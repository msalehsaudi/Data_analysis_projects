# %%
import pandas as pd
dataset = 'WA_Fn-UseC_-Telco-Customer-Churn.csv'
df = pd.read_csv(dataset)

# %%
print(df.shape)
df.head(6)
df.info()
# Out:
# (7043, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
org = df.iloc[:]
org.shape
# Out:
# (7043, 21)

# %%
cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']

# %%
def set_approach(a,b):
    return list(set(a)-set(b))

# %%
cols2 = list(org.columns)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
le = LabelEncoder()
cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
org.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
'''cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'Churn']
df = pd.get_dummies(df, columns=cols, drop_first=True)'''
# Out:
# "cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents',\n       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',\n       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',\n       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',\n       'PaymentMethod', 'Churn']\ndf = pd.get_dummies(df, columns=cols, drop_first=True)"

# %%
df.shape
# Out:
# (7043, 21)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %%
df.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
highlyCorr = ['tenure', 'OnlineSecurity', 'OnlineBackup', 'TechSupport', 'Contract', 'PaperlessBilling', 'MonthlyCharges']
org.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
org['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.550192
# Two year          0.240664
# One year          0.209144
# Name: Contract, dtype: float64

# %%
org.query('Churn == "Yes"')['Contract'].value_counts(normalize=True)
# Out:
# Month-to-month    0.885500
# One year          0.088818
# Two year          0.025682
# Name: Contract, dtype: float64

# %%
org.query('Churn == "No"')['Contract'].value_counts(normalize=True)
# Type 0 (Month-to-Month) contracted customers have the highest churn rate 88.5%
# Out:
# Month-to-month    0.429068
# Two year          0.318322
# One year          0.252609
# Name: Contract, dtype: float64

# %%
# Conditional probability of churn given contract type
org.groupby('Contract')['Churn'].value_counts(normalize=True)
# Out:
# Contract        Churn
# Month-to-month  No       0.572903
#                 Yes      0.427097
# One year        No       0.887305
#                 Yes      0.112695
# Two year        No       0.971681
#                 Yes      0.028319
# Name: Churn, dtype: float64

# %%
org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
org['Contract']
# Out:
# 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7043, dtype: object

# %%
org.query('Churn == "Yes"')['tenure'].mean()
# Out:
# 17.979133226324237

# %%
org.query('Churn == "No"')['tenure'].mean()
# Out:
# 37.56996521066873

# %%
df['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
# We bin our tenure values into years
bins = list(range(0,80,12))
org['tenure_bin'] = pd.cut(df['tenure'], bins)

# %%
org.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
# Conditional probability 
org.groupby('tenure_bin')['Churn'].value_counts(normalize=True)
# Out:
# tenure_bin  Churn
# (0, 12]     No       0.523218
#             Yes      0.476782
# (12, 24]    No       0.712891
#             Yes      0.287109
# (24, 36]    No       0.783654
#             Yes      0.216346
# (36, 48]    No       0.809711
#             Yes      0.190289
# (48, 60]    No       0.855769
#             Yes      0.144231
# (60, 72]    No       0.933902
#             Yes      0.066098
# Name: Churn, dtype: float64

# %%
org['tenure_bin'].value_counts(sort=False).reset_index()
# Out:
#       index  tenure_bin
# 0   (0, 12]        2175
# 1  (12, 24]        1024
# 2  (24, 36]         832
# 3  (36, 48]         762
# 4  (48, 60]         832
# 5  (60, 72]        1407

# %%
# All data points belong to unique customers
org['customerID'].nunique() == len(df)
# Out:
# True

# %%
org.query('Churn == "Yes"')['OnlineSecurity'].value_counts(normalize=True).rename('percentage').reset_index()
# Out:
#                  index  percentage
# 0                   No    0.781701
# 1                  Yes    0.157838
# 2  No internet service    0.060460

# %%
org.query('Churn == "No"')['OnlineSecurity'].value_counts(normalize=True)
# People with a 'No' value for the OnlineSecurity columns have the highest churn rate of 78% amongst customers with other values for OnlineSecurity
# Out:
# No                     0.393699
# Yes                    0.333204
# No internet service    0.273096
# Name: OnlineSecurity, dtype: float64

# %%
org.groupby('OnlineSecurity')['Churn'].value_counts(normalize=True)
# Out:
# OnlineSecurity       Churn
# No                   No       0.582333
#                      Yes      0.417667
# No internet service  No       0.925950
#                      Yes      0.074050
# Yes                  No       0.853888
#                      Yes      0.146112
# Name: Churn, dtype: float64

# %%
sns.countplot(x='TechSupport', hue='Churn', data=org);
#

# %%
corr_df = org[['customerID']+cols]

# %%
corr_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Here we find that people that don't have Online Backup are twice as likely to leave the company
org.groupby('OnlineBackup')['Churn'].value_counts(normalize=True)
# Out:
# OnlineBackup         Churn
# No                   No       0.600712
#                      Yes      0.399288
# No internet service  No       0.925950
#                      Yes      0.074050
# Yes                  No       0.784685
#                      Yes      0.215315
# Name: Churn, dtype: float64

# %%
# People that use a paperless billing system are twice as likely to leave the company
# Maybe due to there not being paperwork overhead?
org.groupby('PaperlessBilling')['Churn'].value_counts(normalize=True)
# Out:
# PaperlessBilling  Churn
# No                No       0.836699
#                   Yes      0.163301
# Yes               No       0.664349
#                   Yes      0.335651
# Name: Churn, dtype: float64

# %%
org.query('Churn == "No"')['MonthlyCharges'].mean()
# Out:
# 61.2651236953999

# %%
org.query('Churn == "Yes"')['MonthlyCharges'].mean()
# Out:
# 74.4413322632423

# %%
mc_bins = range(0, 120, 20)
org['MonthlyCharges_bin'] = pd.cut(org['MonthlyCharges'], mc_bins)

# %%
sns.countplot(x='MonthlyCharges_bin', hue='Churn', data=org);
plt.show();

# %%
org['MonthlyCharges_bin'].value_counts()
# Out:
# (80, 100]    1764
# (60, 80]     1459
# (20, 40]     1182
# (40, 60]     1080
# (0, 20]       656
# Name: MonthlyCharges_bin, dtype: int64

# %%
# Conditional probability of leaving the company given the monthly charges
org.groupby('MonthlyCharges_bin')['Churn'].value_counts(normalize=True)
# We find that the higher the monthly charge, the more likely the customer will leave the company
# Out:
# MonthlyCharges_bin  Churn
# (0, 20]             No       0.911585
#                     Yes      0.088415
# (20, 40]            No       0.868020
#                     Yes      0.131980
# (40, 60]            No       0.744444
#                     Yes      0.255556
# (60, 80]            No       0.675805
#                     Yes      0.324195
# (80, 100]           No       0.629819
#                     Yes      0.370181
# Name: Churn, dtype: float64

# %%
mc_means = []
for _ in range(10000):
    bootsamp = org.sample(len(org), replace=True)
    mc_mean = bootsamp.query('Churn == "Yes"')['MonthlyCharges'].mean()
    mc_means.append(mc_mean)
plt.hist(mc_means);

# %%
pop_mean = org.query('Churn == "Yes"')['MonthlyCharges'].mean()

# %%
import numpy as np
lower, higher = np.percentile(mc_means, 2.5), np.percentile(mc_means, 97.5)

# %%
plt.hist(mc_means)
plt.axvline(lower, color='red')
plt.axvline(higher, color='red')
plt.axvline(pop_mean, color='yellow')
plt.show()

# %%
dataframe = pd.read_csv('data.csv')

# %%
dataframe.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
sb.relplot(x="BorrowerRate", y="EstimatedEffectiveYield", hue="ProsperRating (Alpha)", size="AvailableBankcardCredit_bins",
            sizes=(80, 200), alpha=.5, palette="muted",
            height=6, data=dataframe)
plt.xlim([0, .5])
plt.xlabel('Borrower Rate')


plt.ylabel('Estimated Effective Yield')
plt.show()

# %%
import seaborn as sb
def mean_poly(x, y, bins = 10, **kwargs):
    """ Custom adapted line plot code. """
    # set bin edges if none or int specified
    if type(bins) == int:
        bins = np.linspace(x.min(), x.max(), bins+1)
    bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2

    # compute counts
    data_bins = pd.cut(x, bins, right = False,
                       include_lowest = True)
    means = y.groupby(data_bins).mean()

    # create plot
    plt.errorbar(x = bin_centers, y = means, **kwargs)

bin_edges = np.arange(20, dataframe['Overall'].max()+0.5, 1)
g = sb.FacetGrid(data = dataframe, hue = 'Preferred', size = 5)
g.map(mean_poly, "Nationality", "Overall", bins = bin_edges)
g.set_ylabels('mean(Overall)')
g.add_legend()
# Out:
# C:\Users\Mohammad Saudi\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Preferred'
#
# ...

# %%
def mean_poly(x, y, bins = 10, **kwargs):
    """ Custom adapted line plot code. """
    # set bin edges if none or int specified
    if type(bins) == int:
        bins = np.linspace(x.min(), x.max(), bins+1)
    bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2

    # compute counts
    data_bins = pd.cut(x, bins, right = False,
                       include_lowest = True)
    means = y.groupby(data_bins).mean()

    # create plot
    plt.errorbar(x = bin_centers, y = means, **kwargs)

bin_edges = np.arange(0.25, df['num_var1'].max()+0.5, 0.5)
g = sb.FacetGrid(data = df, hue = 'cat_var2', size = 5)
g.map(mean_poly, "num_var1", "num_var2", bins = bin_edges)
g.set_ylabels('mean(num_var2)')
g.add_legend()

# %%
# This function should remove highly correlated descriptors(columns) from any dataset with specified correlation threshold
def correlation(dataset, threshold):
    """ Removes all columns with internal correlation with each other if they are than the specified 'threshold' """
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold or corr_matrix.iloc[i, j] <= -threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

    print(dataset.columns)

# %%
loan_corr_abs1 = list(abs(dataframe.corr()['Overall'][:]).nlargest(12).index)

loan_corr1 = dataframe[loan_corr_abs1]

correlation(loan_corr1, 0.8)
plt.figure(figsize = [14, 10])
sb.heatmap(abs(loan_corr1.corr()), annot = True, fmt = '.3f',
           cmap = 'viridis_r', center = 0)
plt.show();
# Out:
# Index(['Overall', 'Composure', 'Potential', 'Special',
#        'International Reputation', 'Vision', 'Age'],
#       dtype='object')
